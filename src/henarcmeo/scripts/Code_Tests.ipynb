# %%
# %load_ext autoreload
# %autoreload 2

# %%
from henarcmeo.core.main import Henarcmeo

session = Henarcmeo(
    root_folder="D:/henarcmeo_hf",
    hf_repo_id=None,
    project_name="henarcmeo",
    structure_file="structure.parquet"
)
# Out:
# read structure from local

# %%
session.structure.structure_df
# Out:
#                                          relative_path  is_folder  file_size  \
# 0                                         datasets_AUX       True        NaN
# 1                                          datasets_EO       True        NaN
# 2                                           Embeddings       True        NaN
# 3                                      index_structure       True        NaN
# 4                                     metadata_current       True        NaN
# ..                                                 ...        ...        ...
# 97   metadata_previous\scene_parameters\s1rtc_scene...      False        0.0
# 98   metadata_previous\scene_parameters\s2l2a_scene...      False        0.0
# 99    metadata_previous\sources\eo_aux_sources.parquet      False        0.0
# 100  metadata_previous\sources\licenses_and_access....      False        0.0
# 101                               versions\v0_info.txt      False        0.0
#
#     file_extension  row_count parquet_metadata
# 0             None        NaN             None
# 1             None        NaN             None
# 2             None        NaN             None
# 3             None        NaN             None
# 4             None        NaN             None
# ..             ...        ...              ...
# 97        .parquet        NaN             None
# 98        .parquet        NaN             None
# 99        .parquet        NaN             None
# 100       .parquet        NaN             None
# 101           .txt        NaN             None
#
# [102 rows x 6 columns]

# %%
# df = session.structure.create_structure_from_local(out_format="parquet")
df = session.structure.create_structure_from_local(out_format="parquet")                                                                                                                                                                                                                                                                                                
session.summary()
# Out:
# Warning: Could not extract metadata from D:\henarcmeo_hf\datasets_AUX\DEM\SRTM\CopDEM30_template.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\datasets_AUX\DEM\SRTM\SRTM_template.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\datasets_AUX\Landcover\ESA_WorldCover\ESA_WorldCover_template.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\datasets_AUX\Landcover\ESRI_LC\2024\ESRI_LULC_template.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\index_structure\grids_index.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\index_structure\metadata_index.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\index_structure\structure_old.parquet: Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\data_metadata\data_index.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_100m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_12000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_120000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_1200m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_300m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_6000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\grids_geo\grid_600m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\integrity\diversity_thresholds.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\scene_parameters\landsat_scene_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\scene_parameters\s1rtc_scenes_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\scene_parameters\s2l2a_scene_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\sources\licenses_and_access.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\sources\source_catalog.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\thematic_metadata\metadata_climate.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\thematic_metadata\metadata_ghsl.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\thematic_metadata\metadata_ipcc_forest.parquet: Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\thematic_metadata\metadata_lc.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_current\thematic_metadata\metadata_regions.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\aux_metadata\metadata_climate.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\aux_metadata\metadata_ghsl.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\aux_metadata\metadata_ipcc_forest.parquet: Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\aux_metadata\metadata_lc.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\aux_metadata\metadata_regions.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\data_metadata\data_index.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_100m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_12000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_120000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_1200m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_300m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_6000.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\grids_geo\grid_600m.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\scene_parameters\landsat_scene_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\scene_parameters\s1rtc_scenes_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\scene_parameters\s2l2a_scene_params.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\sources\eo_aux_sources.parquet: Parquet file size is 0 bytes
# Warning: Could not extract metadata from D:\henarcmeo_hf\metadata_previous\sources\licenses_and_access.parquet: Parquet file size is 0 bytes
# parquet saved
# Project: henarcmeo
# Local root: D:\henarcmeo_hf
# HF repo: None
# Structure file: structure.parquet
# Cache dir: .cache
# Grid root: None
# Metadata root: None

# %%
df.to_csv("D:/structure.csv", index=False)

# %%
import pandas as pd
